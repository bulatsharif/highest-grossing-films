# %% [markdown]
# # Assignment 1; Part 1: Scrapping the Wikipedia and Population the database #
#
# For the scrapping framework I have chosen Scrapy, since it have been seen as a more powerful tool than BeatifoulSoup. \

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# ## Scrapy Spider ##
# To scrap the Wikipedia page, in Scrapy we have to define so-called "Spider", which will go through the needed pages. \
# - First of all, I provide a name for this spider, to be invoked in future.
# - Secondly, I provide the start url page. I plan to scrap top-50 table, and extract from this table links to the movie main page itself, from which I will extract additional information.
# - Then I create two function: 'parse' and 'parse_film_details'. The 'parse' function is default function which will be called on every new page request; while 'parse_film_details' is invoked on the movie main page request;

# %%
class FilmDetailSpider(scrapy.Spider):
    name = "film_details" # the name of the spider, to be invoked in future.

    start_urls = ["https://en.wikipedia.org/wiki/List_of_highest-grossing_films"] # the url from which we will start scrapping
    
    custom_settings = {
        'FEEDS': { 'data.json': { 'format': 'json', 'encoding': 'utf-8', 'overwrite': True}}
    } # these settings is needed, for example, to save the output of scrapping in json file.

    def parse(self, response):
        table = response.xpath("//table[contains(@class, 'wikitable')][1]/tbody") # go to the table path on the web-page
        rows = table.xpath("./tr")[1:]  # Skip header row

        for row in rows:
            # Extract title and link
            title_element = row.xpath("./th[@scope='row']//i/a | ./th[@scope='row']//span/i/a")  # Handle both cases
            title = title_element.xpath("text()").get()
            link = title_element.xpath("@href").get()

            # Extract year (handle both direct text and data-sort-value cases)
            year_column = row.xpath("./td[4]")
            year = year_column.xpath("text()").get() or year_column.xpath("@data-sort-value").get()

            if title and link:
                # if title and link present, follow the link to the main page about the movie, invoke different parses
                yield response.follow(link, self.parse_film_details, meta={'title': title, 'year': year})




    def parse_film_details(self, response):
        # these values came from table, which we scrapped earlier, so just move here
        title = response.meta['title']
        year = response.meta['year']

        directors = response.xpath("//th[contains(text(),'Directed by')]/following-sibling::td//li//text()").getall()
        # If no <li> elements, get text from <td> (single director case)
        if not directors:
            directors = response.xpath("//th[contains(text(),'Directed by')]/following-sibling::td//a/text()").getall()
        # Convert list to string
        director_str = ", ".join(directors).strip() if directors else None

        box_office = response.xpath("//th[contains(text(),'Box office')]/following-sibling::td//text()").get()
        
        countries = response.xpath("//th[contains(text(),'Country') or contains(text(),'Countries')]/following-sibling::td//li//text()").getall()
        if not countries:
            countries = response.xpath("//th[contains(text(),'Country') or contains(text(),'Countries')]/following-sibling::td//text()").getall()
        countries_str = ", ".join(countries).strip() if countries else None

        yield {
            'Title': title,
            'Year': year,  
            'Director': director_str,            
            'Countries' : countries_str,
            'Box Office': box_office.strip() if box_office else None,
        }

# %% [markdown]
# ## Starting the Spider ##
# Finally, after everything is imported and the spider is configured, we can launch the spider to scrap the website, starting from initial web-page

# %%
process = CrawlerProcess()
process.crawl(FilmDetailSpider)
process.start()
# Out:
# 2025-02-20 20:22:53 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# 2025-02-20 20:22:53 [scrapy.utils.log] INFO: Versions: lxml 5.3.1.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.12.5 (v3.12.5:ff3bc82f7c9, Aug  7 2024, 05:32:06) [Clang 13.0.0 (clang-1300.0.29.30)], pyOpenSSL 25.0.0 (OpenSSL 3.4.1 11 Feb 2025), cryptography 44.0.1, Platform macOS-15.2-arm64-arm-64bit
# 2025-02-20 20:22:53 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-02-20 20:22:53 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 
(referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-20 20:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Inside_Out_2>
# {'Title': 'Inside Out 2', 'Year': '2024\n', 'Director': 'Kelsey Mann', 'Countries': 'United States', 'Box Office': '$1.699\xa0billion'}
# 2025-02-20 20:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Spider-Man:_No_Way_Home>
# {'Title': 'Spider-Man: No Way Home', 'Year': '2021\n', 'Director': 'Jon Watts', 'Countries': 'United States', 'Box Office': '$1.953 billion'}
# 2025-02-20 20:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Titanic_(1997_film)>
# {'Title': 'Titanic', 'Year': '1997\n', 'Director': 'James Cameron', 'Countries': 'United States', 'Box Office': '$2.264\xa0billion'}
# 2025-02-20 20:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avengers:_Infinity_War>
# {'Title': 'Avengers: Infinity War', 'Year': '2018\n', 'Director': 'Anthony Russo, Joe Russo', 'Countries': 'United States', 'Box Office': '$2.052\xa0billion'}
# 2025-02-20 20:22:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Top_Gun:_Maverick>
# {'Title': 'Top Gun: Maverick', 'Year': '2022\n', 'Director': 'Joseph Kosinski', 'Countries': 'United States', 'Box Office': '$1.496\xa0billion'}
# 2025-02-20 20:22:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-20 20:22:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avatar:_The_Way_of_Water>
# {'Title': 'Avatar: The Way of Water', 'Year': '2022\n', 'Director': 'James Cameron', 'Countries': 'United States', 'Box Office': '$2.320\xa0billion'}
# 2025-02-20 20:22:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/Avengers:_Endgame> (referer: https://en.wikipedia.org/wiki/List_of_highest-grossing_films)
# 2025-02-20 20:22:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/Avengers:_Endgame>
# {'Title': 'Avengers: Endgame', 'Year': '2019\n', 'Director': 'Anthony Russo, Joe Russo', 'Countries': 'United States', 'Box Office': '$2.799'}
# 2025-02-20 20:22:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-02-20 20:22:59 [scrapy.extensions.feedexport] INFO: Stored json feed (50 items) in: data.json
# 2025-02-20 20:22:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 23978,
#  'downloader/request_count': 51,
#  'downloader/request_method_count/GET': 51,
#  'downloader/response_bytes': 6081512,
#  'downloader/response_count': 51,
#  'downloader/response_status_count/200': 51,
#  'elapsed_time_seconds': 5.829108,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 2, 20, 17, 22, 59, 494533, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 35803762,
#  'httpcompression/response_count': 51,
#  'item_scraped_count': 50,
#  'items_per_minute': None,
#  'log_count/DEBUG': 102,
#  'log_count/INFO': 11,
#  'memusage/max': 104103936,
#  'memusage/startup': 104103936,
#  'request_depth_max': 1,
#  'response_received_count': 51,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 51,
#  'scheduler/dequeued/memory': 51,
#  'scheduler/enqueued': 51,
#  'scheduler/enqueued/memory': 51,
#  'start_time': datetime.datetime(2025, 2, 20, 17, 22, 53, 665425, tzinfo=datetime.timezone.utc)}
# 2025-02-20 20:22:59 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Data Preprocessing ##
# Now, after we got the json file, the data can be not clean and requires preprocessing. \
# For example, we need to properly handle the countries of origin for the movie, and also format the box-office

# %%
import pandas as pd


df = pd.read_json('data.json')
print(df.columns)
df.head()
# Out:
# Index(['Title', 'Year', 'Director', 'Countries', 'Box Office'], dtype='object')
#                                         Title  Year  \
# 0                                      Avatar  2009
# 1  Pirates of the Caribbean: Dead Man's Chest  2006
# 2                                     Aladdin  2019
# 3                Rogue One: A Star Wars Story  2016
# 4                                     Moana 2  2024
#
#                                             Director  \
# 0                                      James Cameron
# 1                                     Gore Verbinski
# 2                                        Guy Ritchie
# 3                                     Gareth Edwards
# 4  David Derrick Jr., [, 1, ], Jason Hand, [, 1, ...
#
#                                          Countries      Box Office
# 0  United Kingdom, [, 2, ], United States, [, 2, ]  $2.923 billion
# 1                                    United States  $1.066 billion
# 2                                    United States  $1.054 billion
# 3                                    United States  $1.059 billion
# 4                                    United States   $1.05 billion

# %% [markdown]
# ### Preprocessing Countries ###
# If you involve .head() on the DataFrame, you will be observe that several entries for countries column is not clear. (e.g. for Avatar we have "United Kingdom, [, 2,] ....") \
# To deal with that, let manually extract the presented countries in the list, and input the correct values for each movie

# %%
countries = [] # This will include the proper countries
for idx, row in df.iterrows():
    countries_individ = str(row[df.columns[3]]).strip()
    countries.append(countries_individ) # Iterate through the rows and add all possible countries in the table
countries_unique = set(countries) # Get unique values for each country
s= ''.join(str(x) for x in list(countries_unique)) # will be needed in future
cleaned = set([x for x in s.split() if len(x) > 2]) # now we can obsere more cleaned countries list
# here we have to manually print this set, and define proper countries
countries = ['China', 'Germany', 'United Kingdom', 'United States', 'New Zealand']

countries_table = [] # now let's create another column with proper countries
for idx, row in df.iterrows(): # iterate over rows
    processed_countries = []
    countries_individ = str(row[df.columns[3]])
    for countr in countries: # iterate over each proper country in the given row
        for s in countr.split(" "): # We split the string with country to extract keywords
            if s in countries_individ and s != 'United': # if the keywords present in this row, add this country to the new entry for that row
                processed_countries.append(countr) # != 'United' because there are UK and USA, to distinguish.
    countries_table.append(','.join(set(processed_countries)))
    
df['Countries'] = countries_table #Finally, change the columns with proper one

# %% [markdown]
# Observe the dataset again, perform some small changes

# %%
df.columns[0]
df.head(50)
df.at[4, 'Director'] = 'David Derrick Jr, Jason Hand, Dana Ledoux Miller' # The only 1 entry with bad Director names.
df.loc[4]['Director']
# Out:
# 'David Derrick Jr, Jason Hand, Dana Ledoux Miller'

# %%
df.head(50)
# Out:
#                                             Title  Year  \
# 0                                          Avatar  2009
# 1      Pirates of the Caribbean: Dead Man's Chest  2006
# 2                                         Aladdin  2019
# 3                    Rogue One: A Star Wars Story  2016
# 4                                         Moana 2  2024
# 5                                     Toy Story 3  2010
# 6       Star Wars: Episode I – The Phantom Menace  1999
# 7     Pirates of the Caribbean: On Stranger Tides  2011
# 8                                     Toy Story 4  2019
# 9                                 Despicable Me 3  2017
# 10               Star Wars: The Rise of Skywalker  2019
# 11                          The Dark Knight Rises  2012
# 12                Transformers: Age of Extinction  2014
# 13                                          Joker  2019
# 14                                  Jurassic Park  1993
# 15                                        Skyfall  2012
# 16                      Spider-Man: Far From Home  2019
# 17                 Transformers: Dark of the Moon  2011
# 18                                        Minions  2015
# 19                                        Aquaman  2018
# 20                                  Incredibles 2  2018
# 21                     Captain America: Civil War  2016
# 22  The Lord of the Rings: The Return of the King  2003
# 23                                     Iron Man 3  2013
# 24                        The Fate of the Furious  2017
# 25                                 Captain Marvel  2019
# 26                           Beauty and the Beast  2017
# 27  Harry Potter and the Deathly Hallows – Part 2  2011
# 28                       Star Wars: The Last Jedi  2017
# 29                                         Frozen  2013
# 30                 Jurassic World: Fallen Kingdom  2018
# 31                                       Frozen 2  2019
# 32                                         Barbie  2023
# 33                    The Super Mario Bros. Movie  2023
# 34                                  Black Panther  2018
# 35                        Avengers: Age of Ultron  2015
# 36                           Deadpool & Wolverine  2024
# 37                                      Furious 7  2015
# 38                                  The Lion King  2019
# 39                                   The Avengers  2012
# 40                                 Jurassic World  2015
# 41                                       Ne Zha 2  2025
# 42                   Star Wars: The Force Awakens  2015
# 43                                   Inside Out 2  2024
# 44                        Spider-Man: No Way Home  2021
# 45                                        Titanic  1997
# 46                         Avengers: Infinity War  2018
# 47                              Top Gun: Maverick  2022
# 48                       Avatar: The Way of Water  2022
# 49                              Avengers: Endgame  2019
#
#                                             Director  \
# 0                                      James Cameron
# 1                                     Gore Verbinski
# 2                                        Guy Ritchie
# 3                                     Gareth Edwards
# 4   David Derrick Jr, Jason Hand, Dana Ledoux Miller
# 5                                        Lee Unkrich
# 6                                       George Lucas
# 7                                       Rob Marshall
# 8                                        Josh Cooley
# 9                          Pierre Coffin, Kyle Balda
# 10                                      J. J. Abrams
# 11                                 Christopher Nolan
# 12                                       Michael Bay
# 13                                     Todd Phillips
# 14                                  Steven Spielberg
# 15                                        Sam Mendes
# 16                                         Jon Watts
# 17                                       Michael Bay
# 18                         Pierre Coffin, Kyle Balda
# 19                                         James Wan
# 20                                         Brad Bird
# 21                          Anthony Russo, Joe Russo
# 22                                     Peter Jackson
# 23                                       Shane Black
# 24                                      F. Gary Gray
# 25                            Anna Boden, Ryan Fleck
# 26                                       Bill Condon
# 27                                       David Yates
# 28                                      Rian Johnson
# 29                          Chris Buck, Jennifer Lee
# 30                                      J. A. Bayona
# 31                          Chris Buck, Jennifer Lee
# 32                                      Greta Gerwig
# 33                    Aaron Horvath, Michael Jelenic
# 34                                      Ryan Coogler
# 35                                       Joss Whedon
# 36                                        Shawn Levy
# 37                                         James Wan
# 38                                       Jon Favreau
# 39                                       Joss Whedon
# 40                                   Colin Trevorrow
# 41                                            Jiaozi
# 42                                      J. J. Abrams
# 43                                       Kelsey Mann
# 44                                         Jon Watts
# 45                                     James Cameron
# 46                          Anthony Russo, Joe Russo
# 47                                   Joseph Kosinski
# 48                                     James Cameron
# 49                          Anthony Russo, Joe Russo
#
#                             Countries       Box Office
# 0        United Kingdom,United States   $2.923 billion
# 1                       United States   $1.066 billion
# 2                       United States   $1.054 billion
# 3                       United States   $1.059 billion
# 4                       United States    $1.05 billion
# 5                       United States   $1.067 billion
# 6                       United States   $1.047 billion
# 7                       United States   $1.046 billion
# 8                       United States   $1.074 billion
# 9                       United States           $1.035
# 10                      United States   $1.077 billion
# 11       United Kingdom,United States   $1.115 billion
# 12                      United States   $1.104 billion
# 13                      United States   $1.079 billion
# 14                      United States   $1.058 billion
# 15       United Kingdom,United States   $1.109 billion
# 16                      United States   $1.133 billion
# 17                      United States   $1.124 billion
# 18                      United States   $1.159 billion
# 19                      United States   $1.152 billion
# 20                      United States   $1.243 billion
# 21                      United States           $1.155
# 22  United States,New Zealand,Germany   $1.151 billion
# 23                      United States   $1.266 billion
# 24                United States,China   $1.236 billion
# 25                      United States   $1.131 billion
# 26                      United States           $1.266
# 27       United Kingdom,United States   $1.342 billion
# 28                      United States           $1.334
# 29                      United States   $1.280 billion
# 30                United States,China    $1.31 billion
# 31                      United States           $1.453
# 32       United Kingdom,United States   $1.446 billion
# 33                      United States   $1.360 billion
# 34                      United States    $1.35 billion
# 35                      United States   $1.405 billion
# 36                      United States   $1.338 billion
# 37                United States,China   $1.515 billion
# 38                      United States   $1.657 billion
# 39                      United States   $1.521 billion
# 40                      United States   $1.671 billion
# 41                              China  US$1.71 billion
# 42                      United States            $2.07
# 43                      United States   $1.699 billion
# 44                      United States   $1.953 billion
# 45                      United States   $2.264 billion
# 46                      United States   $2.052 billion
# 47                      United States   $1.496 billion
# 48                      United States   $2.320 billion
# 49                      United States           $2.799

# %% [markdown]
# ### Handle the Box-office ###
# Now, let's handle the box-office: make the integers correct, and remove dollar signs

# %%
import re


box_office_cleaned = []
for idx, row in df.iterrows(): # iterate over rows
    budget = str(row[df.columns[-1]]).strip() # fetch the box office
    numb_budget = re.findall(r'\d+', budget) # extract the numeric value
    box_office_cleaned.append(numb_budget[0] + numb_budget[1] + '0' * (9 - len(numb_budget[1]))) # add needed zeros (according to billion)
    
df.columns
df['Box Office'] = box_office_cleaned # change column with proper one
df.head(5)
# Out:
#                                         Title  Year  \
# 0                                      Avatar  2009
# 1  Pirates of the Caribbean: Dead Man's Chest  2006
# 2                                     Aladdin  2019
# 3                Rogue One: A Star Wars Story  2016
# 4                                     Moana 2  2024
#
#                                            Director  \
# 0                                     James Cameron
# 1                                    Gore Verbinski
# 2                                       Guy Ritchie
# 3                                    Gareth Edwards
# 4  David Derrick Jr, Jason Hand, Dana Ledoux Miller
#
#                       Countries  Box Office
# 0  United Kingdom,United States  2923000000
# 1                 United States  1066000000
# 2                 United States  1054000000
# 3                 United States  1059000000
# 4                 United States  1050000000

# %% [markdown]
# ## Create a Database ##
# Now, let's deal with database. For this Assignment I will use SQLite, since it is great choice for educational project, and is very easy.
# Let's start with importing the required libraries

# %%
from sqlalchemy import create_engine, ForeignKey, Column, String, Integer, CHAR, MetaData, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %% [markdown]
# Let's declare the table, which we will populate with our information

# %%
Base = declarative_base()

class Film(Base):
    __tablename__ = "films"
    
    
    id = Column("id", Integer, primary_key=True, autoincrement=True)
    title = Column("title", String, nullable=False)
    release_year = Column("release_year", Integer)
    director = Column("director", String)
    box_office = Column("box_office", String)
    country = Column("country", String)
    
    def __init__(self, title, release_year, director, country, box_office):
        self.title = title
        self.release_year = release_year
        self.director = director
        self.box_office = box_office
        self.country = country
# Out:
# 2025-02-20 20:23:37 [py.warnings] WARNING: /var/folders/yv/pfr0hn755gjbm9trsh5xk0ch0000gn/T/ipykernel_18597/786173885.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# Let's create engine, create tables, and populate it with our scrapped dataset.

# %%
engine = create_engine("sqlite:///films.db")
Base.metadata.create_all(bind=engine)


Session = sessionmaker(bind=engine)
session = Session()

for idx, row in df.iterrows():
    film_attributes = [row[df.columns[i]] for i in range(len(df.columns))]
    film = Film(film_attributes[0], film_attributes[1], film_attributes[2], film_attributes[3], film_attributes[4])
    session.add(film)

session.commit()

# %% [markdown]
# Finally, let's export the database content to the json file, as stated in the assignment

# %%
import json

metadata = MetaData()
metadata.reflect(bind=engine)

table_name = "films"
table = metadata.tables[table_name]

with engine.connect() as connection:
    result = connection.execute(table.select()).mappings().all()

data_list = [dict(row) for row in result]

json_file = "movies.json"
with open(json_file, "w", encoding="utf-8") as f:
    json.dump(data_list, f, indent=4)
